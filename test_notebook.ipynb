# %% [markdown]
# # Colab VSCode Test Notebook
#
# This notebook is used to test running Jupyter notebooks in VSCode, similar to Google Colab experience.

# %%
# Test 1: Basic Python execution
print("Hello from VSCode!")
print("Testing Colab-like functionality in VSCode")

# %%
# Test 2: Import common libraries
import sys
import platform

print(f"Python version: {sys.version}")
print(f"Platform: {platform.platform()}")

# %%
# Test 3: Simple computation
numbers = [1, 2, 3, 4, 5]
squared = [n**2 for n in numbers]
print(f"Original: {numbers}")
print(f"Squared: {squared}")
print(f"Sum: {sum(squared)}")

# %%
# Test 4: Verify notebook environment
try:
    import numpy as np
    print(f"NumPy version: {np.__version__}")
    arr = np.array([1, 2, 3, 4, 5])
    print(f"NumPy array: {arr}")
    print(f"Mean: {arr.mean()}")
except ImportError:
    print("NumPy not installed. Install with: pip install numpy")

# %% [markdown]
# ## Success!
#
# If you can run all cells above without errors, your VSCode environment is set up correctly for Colab-like notebook execution!
